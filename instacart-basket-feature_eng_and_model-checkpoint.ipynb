# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import squarify 
import os 
import warnings
warnings.filterwarnings("ignore")

import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from lightgbm import LGBMModel,LGBMClassifier
# view accuracy
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, roc_curve, auc

import matplotlib.pyplot as plt
import zipfile
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import gc 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
zip_orders_train = "order_products__train.csv"
zip_orders_prior = "order_products__prior.csv"
zip_orders = 'orders.csv'
zip_products = 'products.csv'
zip_departments = 'departments.csv'
zip_aisles = 'aisles.csv'

archive_orders_train = zipfile.ZipFile("../instacart-market-basket-analysis/"+zip_orders_train+".zip","r")
archive_orders_prior = zipfile.ZipFile("../instacart-market-basket-analysis/"+zip_orders_prior+".zip","r")
archive_orders = zipfile.ZipFile("../instacart-market-basket-analysis/"+zip_orders+".zip","r")
archive_products = zipfile.ZipFile("../instacart-market-basket-analysis/"+zip_products+".zip","r")
archive_departments = zipfile.ZipFile("../instacart-market-basket-analysis/"+zip_departments+".zip","r")
archive_aisles = zipfile.ZipFile("../instacart-market-basket-analysis/"+zip_aisles+".zip","r")

df_order_train = pd.read_csv(archive_orders_train.open('order_products__train.csv'))
df_order_prior = pd.read_csv(archive_orders_prior.open('order_products__prior.csv'))
df_order = pd.read_csv(archive_orders.open('orders.csv'))
df_product = pd.read_csv(archive_products.open('products.csv'))
df_departments = pd.read_csv(archive_departments.open('departments.csv'))
df_aisles = pd.read_csv(archive_aisles.open('aisles.csv'))

# %% [markdown]
# Let's explore the dataset.

# %%
df_merged = pd.merge(df_product,df_aisles,on='aisle_id')
df_merged = pd.merge(df_merged,df_departments,on='department_id')

# %%
del [df_aisles, df_departments]

# %%
df_order.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_order['eval_set'].value_counts()
# Out:
# prior    3214874
# train     131209
# test       75000
# Name: eval_set, dtype: int64

# %%
prior = df_order[df_order['eval_set']=='prior']

# %%
prior = pd.merge(prior,df_order_prior,on='order_id')

# %%
prior.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
df_merged.head()
# Out:
#    product_id                                    product_name  aisle_id  \
# 0           1                      Chocolate Sandwich Cookies        61
# 1          78               Nutter Butter Cookie Bites Go-Pak        61
# 2         102                           Danish Butter Cookies        61
# 3         172  Gluten Free All Natural Chocolate Chip Cookies        61
# 4         285                    Mini Nilla Wafers Munch Pack        61
#
#    department_id          aisle department
# 0             19  cookies cakes     snacks
# 1             19  cookies cakes     snacks
# 2             19  cookies cakes     snacks
# 3             19  cookies cakes     snacks
# 4             19  cookies cakes     snacks

# %% [markdown]
# Only the days since prior order has null values.

# %%
prior[prior['days_since_prior_order'].isnull()]
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434368   3154581   206209    prior             1          3
# 32434369   3154581   206209    prior             1          3
# 32434370   3154581   206209    prior             1          3
# 32434371   3154581   206209    prior             1          3
# 32434372   3154581   206209    prior             1          3
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# 2                         8                     NaN       12427
# 3                         8                     NaN       26088
# 4                         8                     NaN       26405
# ...                     ...                     ...         ...
# 32434368                 11                     NaN       20073
# 32434369                 11                     NaN       13176
# 32434370                 11                     NaN       20842
# 32434371                 11                     NaN       23594
# 32434372                 11                     NaN       25837
#
#           add_to_cart_order  reordered
# 0                         1          0
# 1                         2          0
# 2                         3          0
# 3                         4          0
# 4                         5          0
# ...                     ...        ...
# 32434368                  9          0
# 32434369                 10          0
# 32434370                 11          0
# 32434371                 12          0
# 32434372                 13          0
#
# [2078068 rows x 10 columns]

# %% [markdown]
# All the first orders of a customer are Nan. We can replace this value using 0

# %%
prior['days_since_prior_order'] = prior['days_since_prior_order'].fillna(0)

# %%
prior.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# dtype: int64

# %%
#Total number of orders placed by each users
users = prior.groupby(by='user_id')['order_number'].aggregate('max').to_frame('u_num_of_orders').reset_index()

# %%
users.isnull().sum()
# Out:
# user_id            0
# u_num_of_orders    0
# dtype: int64

# %%
# Average number of products bought by the user in each purchase.
#1. First getting the total number of products in each order.
total_prd_per_order = prior.groupby(by=['user_id', 'order_id'])['product_id'].aggregate('count').to_frame('total_products_per_order').reset_index()
total_prd_per_order.head()
# Out:
#    user_id  order_id  total_products_per_order
# 0        1    431534                         8
# 1        1    473747                         5
# 2        1    550135                         5
# 3        1   2254736                         5
# 4        1   2295261                         6

# %%
total_prd_per_order.isnull().sum()
# Out:
# user_id                     0
# order_id                    0
# total_products_per_order    0
# dtype: int64

# %%
#2. Getting the average products purchased by each user
avg_products = total_prd_per_order.groupby(by=['user_id'])['total_products_per_order'].mean().to_frame('u_avg_prd').reset_index()

#deleting the total_prd_per_order dataframe
del total_prd_per_order

# %%
avg_products.head()
# Out:
#    user_id  u_avg_prd
# 0        1   5.900000
# 1        2  13.928571
# 2        3   7.333333
# 3        4   3.600000
# 4        5   9.250000

# %%
avg_products.isnull().sum()
# Out:
# user_id      0
# u_avg_prd    0
# dtype: int64

# %%
#dow of most orders placed by each user
from scipy import stats
dow = prior.groupby(by='user_id')['order_dow'].agg(lambda x: stats.mode(x)[0]).to_frame('dow_most_orders_u').reset_index()
dow.head()
# Out:
#    user_id  dow_most_orders_u
# 0        1                  4
# 1        2                  2
# 2        3                  0
# 3        4                  4
# 4        5                  3

# %%
hod = prior.groupby(by='user_id')['order_hour_of_day'].agg(lambda x: stats.mode(x)[0]).to_frame('hod_most_orders_u').reset_index()
hod.head()
# Out:
#    user_id  hod_most_orders_u
# 0        1                  7
# 1        2                  9
# 2        3                 16
# 3        4                 15
# 4        5                 18

# %%
prior = pd.merge(prior,df_merged,on='product_id')
prior.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id        aisle department
# 0         Soda        77              7  soft drinks  beverages
# 1         Soda        77              7  soft drinks  beverages
# 2         Soda        77              7  soft drinks  beverages
# 3         Soda        77              7  soft drinks  beverages
# 4         Soda        77              7  soft drinks  beverages

# %%
prior.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# product_name              0
# aisle_id                  0
# department_id             0
# aisle                     0
# department                0
# dtype: int64

# %%
freq_aisle = prior.groupby(by='user_id')['aisle_id'].agg(lambda x: stats.mode(x)[0]).to_frame('freq_aisle').reset_index()
freq_aisle.head()
# Out:
#    user_id  freq_aisle
# 0        1          77
# 1        2         120
# 2        3          24
# 3        4          38
# 4        5         123

# %%
freq_department = prior.groupby(by='user_id')['department_id'].agg(lambda x: stats.mode(x)[0]).to_frame('freq_department').reset_index()
freq_department.head()
# Out:
#    user_id  freq_department
# 0        1               19
# 1        2               16
# 2        3                4
# 3        4                1
# 4        5                4

# %%
#merging avg_products with users
users = users.merge(avg_products, on='user_id', how='left')
#deleting avg_products
del avg_products
users.head()
# Out:
#    user_id  u_num_of_orders  u_avg_prd
# 0        1               10   5.900000
# 1        2               14  13.928571
# 2        3               12   7.333333
# 3        4                5   3.600000
# 4        5                4   9.250000

# %%
users = users.merge(dow, on='user_id', how='left')
#deleting dow
del dow
users.head()
# Out:
#    user_id  u_num_of_orders  u_avg_prd  dow_most_orders_u
# 0        1               10   5.900000                  4
# 1        2               14  13.928571                  2
# 2        3               12   7.333333                  0
# 3        4                5   3.600000                  4
# 4        5                4   9.250000                  3

# %%
#3. merging hod with users
users = users.merge(hod, on='user_id', how='left')
#deleting dow
del hod
users.head()
# Out:
#    user_id  u_num_of_orders  u_avg_prd  dow_most_orders_u  hod_most_orders_u
# 0        1               10   5.900000                  4                  7
# 1        2               14  13.928571                  2                  9
# 2        3               12   7.333333                  0                 16
# 3        4                5   3.600000                  4                 15
# 4        5                4   9.250000                  3                 18

# %%
#4. merging frequent aisle with users
users = users.merge(freq_aisle, on='user_id', how='left')
#deleting dow
del freq_aisle
users.head()
# Out:
#    user_id  u_num_of_orders  u_avg_prd  dow_most_orders_u  hod_most_orders_u  \
# 0        1               10   5.900000                  4                  7
# 1        2               14  13.928571                  2                  9
# 2        3               12   7.333333                  0                 16
# 3        4                5   3.600000                  4                 15
# 4        5                4   9.250000                  3                 18
#
#    freq_aisle
# 0          77
# 1         120
# 2          24
# 3          38
# 4         123

# %%
#4. merging frequent aisle with users
users = users.merge(freq_department, on='user_id', how='left')
#deleting dow
del freq_department
users.head()
# Out:
#    user_id  u_num_of_orders  u_avg_prd  dow_most_orders_u  hod_most_orders_u  \
# 0        1               10   5.900000                  4                  7
# 1        2               14  13.928571                  2                  9
# 2        3               12   7.333333                  0                 16
# 3        4                5   3.600000                  4                 15
# 4        5                4   9.250000                  3                 18
#
#    freq_aisle  freq_department
# 0          77               19
# 1         120               16
# 2          24                4
# 3          38                1
# 4         123                4

# %%
#number of time a product was purchased.
prd = prior.groupby(by='product_id')['order_id'].agg('count').to_frame('prd_count_p').reset_index()
prd.head()
# Out:
#    product_id  prd_count_p
# 0           1         1852
# 1           2           90
# 2           3          277
# 3           4          329
# 4           5           15

# %%
#products reorder ratio.
reorder_p = prior.groupby(by='product_id')['reordered'].agg('mean').to_frame('p_reordered_ratio').reset_index()
reorder_p.head()
# Out:
#    product_id  p_reordered_ratio
# 0           1           0.613391
# 1           2           0.133333
# 2           3           0.732852
# 3           4           0.446809
# 4           5           0.600000

# %%
#merging the reorder_p with prd
prd = prd.merge(reorder_p, on='product_id', how='left')
#deleting reorder_p
del reorder_p
prd.head()
# Out:
#    product_id  prd_count_p  p_reordered_ratio
# 0           1         1852           0.613391
# 1           2           90           0.133333
# 2           3          277           0.732852
# 3           4          329           0.446809
# 4           5           15           0.600000

# %%
#how many times a user bought the same product.
uxp = prior.groupby(by=['user_id', 'product_id'])['order_id'].agg('count').to_frame('uxp_times_bought').reset_index()
uxp.head()
# Out:
#    user_id  product_id  uxp_times_bought
# 0        1         196                10
# 1        1       10258                 9
# 2        1       10326                 1
# 3        1       12427                10
# 4        1       13032                 3

# %%
#reorder ratio of the user for each product.
reorder_uxp = prior.groupby(by=['user_id', 'product_id'])['reordered'].agg('mean').to_frame('uxp_reordered_ratio').reset_index()
reorder_uxp.head()
# Out:
#    user_id  product_id  uxp_reordered_ratio
# 0        1         196             0.900000
# 1        1       10258             0.888889
# 2        1       10326             0.000000
# 3        1       12427             0.900000
# 4        1       13032             0.666667

# %%
#merging the two dataframes into one
uxp = uxp.merge(reorder_uxp, on=['user_id', 'product_id'], how='left')
#deleting reorder_uxp
del reorder_uxp
uxp.head()
# Out:
#    user_id  product_id  uxp_times_bought  uxp_reordered_ratio
# 0        1         196                10             0.900000
# 1        1       10258                 9             0.888889
# 2        1       10326                 1             0.000000
# 3        1       12427                10             0.900000
# 4        1       13032                 3             0.666667

# %%
#merging users df into uxp
df = uxp.merge(users, on='user_id', how='left')
df.head()
# Out:
#    user_id  product_id  uxp_times_bought  uxp_reordered_ratio  \
# 0        1         196                10             0.900000
# 1        1       10258                 9             0.888889
# 2        1       10326                 1             0.000000
# 3        1       12427                10             0.900000
# 4        1       13032                 3             0.666667
#
#    u_num_of_orders  u_avg_prd  dow_most_orders_u  hod_most_orders_u  \
# 0               10        5.9                  4                  7
# 1               10        5.9                  4                  7
# 2               10        5.9                  4                  7
# 3               10        5.9                  4                  7
# 4               10        5.9                  4                  7
#
#    freq_aisle  freq_department
# 0          77               19
# 1          77               19
# 2          77               19
# 3          77               19
# 4          77               19

# %%
#merging products df into data
df = df.merge(prd, on='product_id', how='left')
df.head()
# Out:
#    user_id  product_id  uxp_times_bought  uxp_reordered_ratio  \
# 0        1         196                10             0.900000
# 1        1       10258                 9             0.888889
# 2        1       10326                 1             0.000000
# 3        1       12427                10             0.900000
# 4        1       13032                 3             0.666667
#
#    u_num_of_orders  u_avg_prd  dow_most_orders_u  hod_most_orders_u  \
# 0               10        5.9                  4                  7
# 1               10        5.9                  4                  7
# 2               10        5.9                  4                  7
# 3               10        5.9                  4                  7
# 4               10        5.9                  4                  7
#
#    freq_aisle  freq_department  prd_count_p  p_reordered_ratio
# 0          77               19        35791           0.776480
# 1          77               19         1946           0.713772
# 2          77               19         5526           0.652009
# 3          77               19         6476           0.740735
# 4          77               19         3751           0.657158

# %%
del [users, prd, uxp]

# %% [markdown]
# Creating the training set

# %%
#keeping only the train eval set from the orders dataframe.
train = df_order.loc[((df_order.eval_set == 'train')), ['user_id', 'order_id']]
train.head()
# Out:
#     user_id  order_id
# 10        1   1187899
# 25        2   1492625
# 49        5   2196797
# 74        7    525192
# 78        8    880375

# %%
#merging the order_future with the data.
df = df.merge(train, on='user_id', how='left')
df.head()
# Out:
#    user_id  product_id  uxp_times_bought  uxp_reordered_ratio  \
# 0        1         196                10             0.900000
# 1        1       10258                 9             0.888889
# 2        1       10326                 1             0.000000
# 3        1       12427                10             0.900000
# 4        1       13032                 3             0.666667
#
#    u_num_of_orders  u_avg_prd  dow_most_orders_u  hod_most_orders_u  \
# 0               10        5.9                  4                  7
# 1               10        5.9                  4                  7
# 2               10        5.9                  4                  7
# 3               10        5.9                  4                  7
# 4               10        5.9                  4                  7
#
#    freq_aisle  freq_department  prd_count_p  p_reordered_ratio   order_id
# 0          77               19        35791           0.776480  1187899.0
# 1          77               19         1946           0.713772  1187899.0
# 2          77               19         5526           0.652009  1187899.0
# 3          77               19         6476           0.740735  1187899.0
# 4          77               19         3751           0.657158  1187899.0

# %%
df.isnull().sum()
# Out:
# user_id                      0
# product_id                   0
# uxp_times_bought             0
# uxp_reordered_ratio          0
# u_num_of_orders              0
# u_avg_prd                    0
# dow_most_orders_u            0
# hod_most_orders_u            0
# freq_aisle                   0
# freq_department              0
# prd_count_p                  0
# p_reordered_ratio            0
# order_id               4833292
# dtype: int64

# %%
df_order_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
#merging the information from the order_proucts_train df into the data_train.
df = df.merge(df_order_train[['product_id', 'order_id', 'reordered']], on=['product_id', 'order_id'], how='left')
df.head()
# Out:
#    user_id  product_id  uxp_times_bought  uxp_reordered_ratio  \
# 0        1         196                10             0.900000
# 1        1       10258                 9             0.888889
# 2        1       10326                 1             0.000000
# 3        1       12427                10             0.900000
# 4        1       13032                 3             0.666667
#
#    u_num_of_orders  u_avg_prd  dow_most_orders_u  hod_most_orders_u  \
# 0               10        5.9                  4                  7
# 1               10        5.9                  4                  7
# 2               10        5.9                  4                  7
# 3               10        5.9                  4                  7
# 4               10        5.9                  4                  7
#
#    freq_aisle  freq_department  prd_count_p  p_reordered_ratio   order_id  \
# 0          77               19        35791           0.776480  1187899.0
# 1          77               19         1946           0.713772  1187899.0
# 2          77               19         5526           0.652009  1187899.0
# 3          77               19         6476           0.740735  1187899.0
# 4          77               19         3751           0.657158  1187899.0
#
#    reordered
# 0        1.0
# 1        1.0
# 2        NaN
# 3        NaN
# 4        1.0

# %%
df.isnull().sum()
# Out:
# user_id                       0
# product_id                    0
# uxp_times_bought              0
# uxp_reordered_ratio           0
# u_num_of_orders               0
# u_avg_prd                     0
# dow_most_orders_u             0
# hod_most_orders_u             0
# freq_aisle                    0
# freq_department               0
# prd_count_p                   0
# p_reordered_ratio             0
# order_id                4833292
# reordered              12479129
# dtype: int64

# %%
#filling the NAN values
df.reordered.fillna(0, inplace=True)

# %%
#setting user_id and product_id as index.
df = df.set_index(['user_id', 'product_id'])


#deleting eval_set, order_id as they are not needed for training.
#df.drop(['order_id'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                     uxp_times_bought  uxp_reordered_ratio  u_num_of_orders  \
# user_id product_id
# 1       196                       10             0.900000               10
#         10258                      9             0.888889               10
#         10326                      1             0.000000               10
#         12427                     10             0.900000               10
#         13032                      3             0.666667               10
#
#                     u_avg_prd  dow_most_orders_u  hod_most_orders_u  \
# user_id product_id
# 1       196               5.9                  4                  7
#         10258             5.9                  4                  7
#         10326             5.9                  4                  7
#         12427             5.9                  4                  7
#         13032             5.9                  4                  7
#
#                     freq_aisle  freq_department  prd_count_p  \
# user_id product_id
# 1       196                 77               19        35791
#         10258               77               19         1946
#         10326               77               19         5526
#         12427               77               19         6476
#         13032               77               19         3751
#
#                     p_reordered_ratio   order_id  reordered
# user_id product_id
# 1       196                  0.776480  1187899.0        1.0
#         10258                0.713772  1187899.0        1.0
#         10326                0.652009  1187899.0        0.0
#         12427                0.740735  1187899.0        0.0
#         13032                0.657158  1187899.0        1.0

# %%
y = df.reordered
X = df.drop(columns=['reordered','order_id'])

# %%
#Split in 75% train and 25% test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 42)
d_train = lgb.Dataset(X_train, label=y_train)
d_test = lgb.Dataset(X_test, label=y_test)

#------------------------Build LightGBM Model-----------------------
train_data=lgb.Dataset(X_train, label=y_train)

#Select Hyper-Parameters
params = {'boosting_type': 'gbdt',
          'max_depth' : -1,
          'objective': 'binary',
          'nthread': 5,
          'num_leaves': 64,
          'learning_rate': 0.07,
          'max_bin': 512,
          'subsample_for_bin': 200,
          'subsample': 1,
          'subsample_freq': 1,
          'colsample_bytree': 0.8,
          'reg_alpha': 1.2,
          'reg_lambda': 1.2,
          'min_split_gain': 0.5,
          'min_child_weight': 1,
          'min_child_samples': 5,
          'scale_pos_weight': 1,
          'num_class' : 1,
          'metric' : 'log-loss'
          }

# Create parameters to search
gridParams = {
    'learning_rate': [0.07],
    'n_estimators': [8,16],
    'num_leaves': [32,96,128],
    'boosting_type' : ['gbdt'],
    'objective' : ['binary'],
    'random_state' : [501], 
    'colsample_bytree' : [0.64, 0.65],
    'subsample' : [0.7,0.75],
    'reg_alpha' : [1, 1.2],
    'reg_lambda' : [ 1.2, 1.4],
    }

# Create classifier to use
model = lgb.LGBMClassifier(boosting_type= 'gbdt',
          objective = 'binary',
          n_jobs = 5, 
          silent = True,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'],
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'],
          subsample_freq = params['subsample_freq'],
          min_split_gain = params['min_split_gain'],
          min_child_weight = params['min_child_weight'],
          min_child_samples = params['min_child_samples'],
          scale_pos_weight = params['scale_pos_weight'])

# View the default model params:
model.get_params().keys()

# Create the grid
grid = GridSearchCV(model, gridParams, verbose=2, cv=5)

# Run the grid
grid.fit(X_train, y_train)

# Print the best parameters found
print(grid.best_params_)
print(grid.best_score_)

# Using parameters already set above, replace in the best from the grid search
params['colsample_bytree'] = grid.best_params_['colsample_bytree']
params['learning_rate'] = grid.best_params_['learning_rate']
# params['max_bin'] = grid.best_params_['max_bin']
params['num_leaves'] = grid.best_params_['num_leaves']
#params['reg_alpha'] = grid.best_params_['reg_alpha']
#params['reg_lambda'] = grid.best_params_['reg_lambda']
params['subsample'] = grid.best_params_['subsample']
# params['subsample_for_bin'] = grid.best_params_['subsample_for_bin']

print('Fitting with params: ')
print(params)

#Train model on selected parameters and number of iterations
lgbm = lgb.train(params,
                 d_train,
                 1000,
                 verbose_eval= 4
                 )

#Predict on test set
predictions_lgbm_prob = lgbm.predict(X_test)
predictions_lgbm_01 = np.where(predictions_lgbm_prob > 0.21, 1, 0) #Turn probability to 0-1 binary output

#--------------------------Print accuracy measures and variable importances----------------------
#Plot Variable Importances
lgb.plot_importance(lgbm, max_num_features=21, importance_type='split')

#Print accuracy
acc_lgbm = accuracy_score(y_test,predictions_lgbm_01)
print('Overall accuracy of Light GBM model:', acc_lgbm)

#Print Area Under Curve
plt.figure()
false_positive_rate, recall, thresholds = roc_curve(y_test, predictions_lgbm_prob)
roc_auc = auc(false_positive_rate, recall)
plt.title('Receiver Operating Characteristic (ROC)')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.show()

print('AUC score:', roc_auc)

#Print Confusion Matrix
plt.figure()
cm = confusion_matrix(y_test, predictions_lgbm_01)
labels = ['no ', 'Default']
plt.figure(figsize=(8,6))
sns.heatmap(cm, xticklabels = labels, yticklabels = labels, annot = True, fmt='d', cmap="Blues", vmin = 0.2);
plt.title('Confusion Matrix')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.show()
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  15.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   15.8s remaining:    0.0s
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=   9.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=   9.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=   9.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=   9.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=   9.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=   9.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=   9.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=   9.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=   9.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=   9.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=   9.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=   9.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=   9.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=   9.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=   9.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=   9.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=   9.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=   9.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=   9.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=   9.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=   9.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  10.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=   9.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=   9.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=32, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=   9.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  10.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  10.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  10.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=96, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  10.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  11.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  11.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  11.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  11.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  11.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  11.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  11.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  11.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  11.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  11.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=8, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  11.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  13.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  13.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  13.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  13.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  13.4s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  13.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.07, n_estimators=16, num_leaves=32, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# ...
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  17.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.7, total=  17.6s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  18.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  18.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  18.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  18.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.2, subsample=0.75, total=  17.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  17.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  17.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  17.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.7, total=  18.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  18.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  18.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  18.1s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1, reg_lambda=1.4, subsample=0.75, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  17.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  17.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  17.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  17.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.7, total=  17.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  18.0s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  17.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.2, subsample=0.75, total=  18.5s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  17.7s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  17.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7, total=  17.8s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  18.2s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  18.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  18.3s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  17.9s
# [CV] boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV]  boosting_type=gbdt, colsample_bytree=0.65, learning_rate=0.07, n_estimators=16, num_leaves=128, objective=binary, random_state=501, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75, total=  18.1s
# [Parallel(n_jobs=1)]: Done 480 out of 480 | elapsed: 107.4min finished
# {'boosting_type': 'gbdt', 'colsample_bytree': 0.64, 'learning_rate': 0.07, 'n_estimators': 8, 'num_leaves': 32, 'objective': 'binary', 'random_state': 501, 'reg_alpha': 1, 'reg_lambda': 1.2, 'subsample': 0.7}
# 0.9377408835459257
# Fitting with params:
# {'boosting_type': 'gbdt', 'max_depth': -1, 'objective': 'binary', 'nthread': 5, 'num_leaves': 32, 'learning_rate': 0.07, 'max_bin': 512, 'subsample_for_bin': 200, 'subsample': 0.7, 'subsample_freq': 1, 'colsample_bytree': 0.64, 'reg_alpha': 1.2, 'reg_lambda': 1.2, 'min_split_gain': 0.5, 'min_child_weight': 1, 'min_child_samples': 5, 'scale_pos_weight': 1, 'num_class': 1, 'metric': 'binary_error'}
# [LightGBM] [Warning] Using too small ``bin_construct_sample_cnt`` may encounter unexpected errors and poor accuracy.
# [LightGBM] [Info] Number of positive: 621406, number of negative: 9359558
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.540130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 316
# [LightGBM] [Info] Number of data points in the train set: 9980964, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.062259 -> initscore=-2.712169
# [LightGBM] [Info] Start training from score -2.712169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Overall accuracy of Light GBM model: 0.9167457421710742
# AUC score: 0.7862784461531375

# %%
f1 = f1_score(y_test, predictions_lgbm_01)

# %%
f1
# Out:
# 0.28702631186067223

# %%
#saving the prediction as a new column in data_test
X_test['prediction'] = predictions_lgbm_01
X_test.head()
# Out:
#                     uxp_times_bought  uxp_reordered_ratio  u_num_of_orders  \
# user_id product_id
# 163834  26283                      3             0.666667               15
# 125629  28204                      2             0.500000               11
# 182247  14183                      3             0.666667                4
# 174134  20169                      1             0.000000               13
# 107989  14429                      1             0.000000               51
#
#                     u_avg_prd  dow_most_orders_u  hod_most_orders_u  \
# user_id product_id
# 163834  26283        7.333333                  0                 12
# 125629  28204       18.272727                  0                 13
# 182247  14183        8.000000                  0                 15
# 174134  20169       16.307692                  5                 10
# 107989  14429       12.431373                  1                 13
#
#                     freq_aisle  freq_department  prd_count_p  \
# user_id product_id
# 163834  26283               83                4        18906
# 125629  28204               83                4        89632
# 182247  14183               24                4         2794
# 174134  20169               24                4         3054
# 107989  14429               24                4         2761
#
#                     p_reordered_ratio  prediction
# user_id product_id
# 163834  26283                0.583148           0
# 125629  28204                0.711922           0
# 182247  14183                0.614889           1
# 174134  20169                0.527505           0
# 107989  14429                0.228178           0

# %%
# Reset the index
final = X_test.reset_index()
# Keep only the required columns to create our submission file
final = final[['product_id', 'user_id', 'prediction']]

#gc.collect()
final.head()
# Out:
#    product_id  user_id  prediction
# 0       26283   163834           0
# 1       28204   125629           0
# 2       14183   182247           1
# 3       20169   174134           0
# 4       14429   107989           0

# %%
#import sklearn.externals.joblib as extjoblib
import joblib
import pickle
joblib.dump(lgbm, 'model_version1.1.pkl', compress = 1)
# Out:
# ['model_version1.1.pkl']

# %%
pipeline = joblib.load('model_version1.1.pkl')

# %%
df = df.reset_index()

# %%
df.head()

# %%
final = final.merge(df[["user_id", "order_id"]], on='user_id', how='left').drop('user_id', axis=1)
final.columns = ['product_id', 'prediction', 'order_id']
final.product_id = final.product_id.astype(int)
final.order_id = final.order_id.astype(int)
final.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-ae93a68a4232> in <module>
# ----> 1 final = final.merge(df[["user_id", "order_id"]], on='user_id', how='left').drop('user_id', axis=1)
#       2 final.columns = ['product_id', 'prediction', 'order_id']
#       3 final.product_id = final.product_id.astype(int)
#       4 final.order_id = final.order_id.astype(int)
#       5 final.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['user_id'] not in index"
